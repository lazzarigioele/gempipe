# %% [markdown]
# # gempipe recon
#
# gempipe includes a Bash command-line application with two subcommand, `recon` and `derive`.
#
#
# `gempipe recon` is designed to reconstruct a presence/absence matrix (PAM) and a draft pan-model, starting from the input genomes or proteomes.
# Below are showed all the options:

# %%
# %%bash
#
# gempipe recon -h
# Out:
# usage: gempipe recon [-h] [-p] [-o] [-t] [-g]
#
# optional arguments:
#   -h, --help         show this help message and exit
#   -p , --processes   Number of parallel processes to use. (default: 1)
#   -o, --overwrite    Delete the working/ directory at the startup. (default:
#                      False)
#   -t , --taxids      Taxids of the species to model (comma separated, for
#                      example '252393,68334'). (default: -)
#   -g , --genomes     Input genome files or folder containing the genomes (see
#                      documentation). (default: -)

# %% [markdown]
# ## Starting from genomes
#
# There are several options to specifiy the input genomes:
#
# * Specify a folder containing the input genomes. They are all assumed to belong to the same species.
#
# ```bash
#     gempipe recon -g my_genomes/
# ```
#
# * Specify a list of input genomes (comma separated).
#
# ```bash
#     gempipe recon -g my_genomes/GCA_001689725.1.fa,my_genomes/GCA_001756855.1.fa,my_genomes/GCA_003058285.2.fa
# ```
#
# * Specify a list of input genomes, grouped by species. This follows a rigid sintax: `SpA@G1,G2,G3+SpB@G4,G5+SpC@G6,G7...`.
#
# ```bash
#     gempipe recon Eda@my_genomes/GCA_001689725.1.fa,my_genomes/GCA_001756855.1.fa,my_genomes/GCA_003058285.2.fa+Eap@my_genomes/GCA_016925695.1.fa,my_genomes/GCA_024169515.1.fa
# ```
#
# * Specify a list of species taxids (comma separated). All the available genome assemblies under those taxids will be automatically dowloaded from NCBI.
#
# ```bash
#     gempipe recon -t 252393,68334
# ```

# %% [markdown]
# ## Starting from proteomes
