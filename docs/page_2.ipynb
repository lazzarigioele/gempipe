# %%
# %load_ext autoreload
# %aimport gempipe, gempipe.moduleA, gempipe.moduleB
# %autoreload 1

# pip install --no-deps --editable .

# %% [markdown]
# # Welcome to gempipe pag 2!
#
# What is gempipe?

# %%
import cobra
import gempipe 

# 1. load a model
model = cobra.io.load_model("textbook")

# 3. plot something
print(gemmap.funcA(model))
print(gemmap.funcB(model))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cobra
#       2 import gempipe
#       4 # 1. load a model
#
# ModuleNotFoundError: No module named 'cobra'
