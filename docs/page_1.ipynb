# %%
# %load_ext autoreload
# %aimport gempipe, gempipe.commons
# %autoreload 1

# pip install --no-deps --editable .

# %% [markdown]
# # Welcome to gempipe pag 1!
#
# What is gempipe?

# %%
import cobra
import gempipe 

# 1. load a model
model = cobra.io.load_model("textbook")

# 3. plot something
print(gempipe.funcA(model))
print(gempipe.funcB(model))

# %%
# %%bash
#
# gempipe -h

# %%
# %%bash
#
# gempipe recon -h

# %%
# %%bash
#
# gempipe derive -h

# %% [markdown]
# These are the non-pip dependencies:
#
# * pigz >= 2.5
