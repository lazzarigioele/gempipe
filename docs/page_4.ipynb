# %% [markdown]
# # gempipe derive
#
# gempipe includes a Bash command-line application with two subcommand, `recon` and `derive`.
#
#
# `gempipe derive` is designed to derive strain-specific and species-specific models, starting from the input PAM and pan-model.
# Below are showed all the options:

# %%
# %%bash
#
# gempipe derive -h
# Out:
# usage: gempipe derive [-h] [-v] [-c]
#
# gempipe v0.0.5, please cite "TODO".
#
# optional arguments:
#   -h, --help     Show this help message and exit.
#   -v, --version  Show version number and exit.
#   -c , --cores   How many parallel processes to use. (default: None)
