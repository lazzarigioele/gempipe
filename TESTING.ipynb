# %%
gempipe recon -g testing/manually_downloaded/GCA_001689725.1.fa,testing/manually_downloaded/GCA_001756855.1.fa,testing/manually_downloaded/GCA_003058285.2.fa

# %%
# %%bash
#
# echo | pwd
#
# # seems still to run in single core...
# for f in testing/manually_downloaded/*; do
#     b=$(basename $f);
#     echo $b;
#     echo $f;
#
#     prokka --force --quiet \
#     --cpus 16 \
#     --outdir testing/prokka_tmp/ \
#     --prefix $b \
#     --noanno \
#     --norrna \
#     --notrna \
#     ${f};
# done
#
#
# prodigal -i testing/prokka_tmp//GCA_014773485.1.fna.fna -c -m -g 11 -p single -f sco -q
# Out:
# /home/jovyan/work
# GCA_001689725.1.fasta
# testing/manually_downloaded/GCA_001689725.1.fasta
# Argument "1.7.8" isn't numeric in numeric lt (<) at /opt/conda/bin/prokka line 259.
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in testing/prokka_tmp//GCA_001689725.1.fasta.gbf
# [tbl2asn-forever] Correcting dates in testing/prokka_tmp//GCA_001689725.1.fasta.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 14-DEC-2023
# GCA_001756855.1.fasta
# testing/manually_downloaded/GCA_001756855.1.fasta
# Argument "1.7.8" isn't numeric in numeric lt (<) at /opt/conda/bin/prokka line 259.
# [tbl2asn-forever] Found Prokka input, correcting dates in .gbf|.sqn files.
# [tbl2asn-forever] Correcting dates in testing/prokka_tmp//GCA_001756855.1.fasta.gbf
# [tbl2asn-forever] Correcting dates in testing/prokka_tmp//GCA_001756855.1.fasta.sqn
# [tbl2asn-forever] Dates changed from 01-JAN-2019 to 14-DEC-2023
# GCA_003058285.2.fna
# ...

# %%
# %%bash
# prodigal -h
# Out:
# Usage:  prodigal [-a trans_file] [-c] [-d nuc_file] [-f output_type]
#                  [-g tr_table] [-h] [-i input_file] [-m] [-n] [-o output_file]
#                  [-p mode] [-q] [-s start_file] [-t training_file] [-v]
#
#          -a:  Write protein translations to the selected file.
#          -c:  Closed ends.  Do not allow genes to run off edges.
#          -d:  Write nucleotide sequences of genes to the selected file.
#          -f:  Select output format (gbk, gff, or sco).  Default is gbk.
#          -g:  Specify a translation table to use (default 11).
#          -h:  Print help menu and exit.
#          -i:  Specify FASTA/Genbank input file (default reads from stdin).
#          -m:  Treat runs of N as masked sequence; don't build genes across them.
#          -n:  Bypass Shine-Dalgarno trainer and force a full motif scan.
#          -o:  Specify output file (default writes to stdout).
#          -p:  Select procedure (single or meta).  Default is single.
# ...
