# %%
# %%bash
# pwd
# Out:
# /home/jovyan/work/src/generated

# %%
import shutil

shutil.copy('mnx_dicts_M/bigg_to_others.pickle', '../gempipe/assets/bigg_to_others_M.pickle')
shutil.copy('mnx_dicts_M/bigg_to_others_extended.pickle', '../gempipe/assets/bigg_to_others_extended_M.pickle')
shutil.copy('mnx_dicts_M/seed_to_others.pickle', '../gempipe/assets/seed_to_others_M.pickle')
shutil.copy('mnx_dicts_M/seed_to_others_extended.pickle', '../gempipe/assets/seed_to_others_extended_M.pickle')

shutil.copy('mnx_dicts_R/bigg_to_others.pickle', '../gempipe/assets/bigg_to_others_R.pickle')
shutil.copy('mnx_dicts_R/bigg_to_others_extended.pickle', '../gempipe/assets/bigg_to_others_extended_R.pickle')
shutil.copy('mnx_dicts_R/seed_to_others.pickle', '../gempipe/assets/seed_to_others_R.pickle')
shutil.copy('mnx_dicts_R/seed_to_others_extended.pickle', '../gempipe/assets/seed_to_others_extended_R.pickle')

print('OK')
# Out:
# OK
